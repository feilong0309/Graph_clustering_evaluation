# %% [markdown]
# PySpark Tutorial
# ================
#
# _Djoerd Hiemstra, University of Twente_
#
# In this tutorial (made for the SIKS/CBS DataCamp, 6 December 2016) we will go over some basic Spark Scala examples following the paper by ([Zahari et al. 2012][1]).
#
# [1]: https://amplab.cs.berkeley.edu/wp-content/uploads/2012/01/nsdi_spark.pdf "Matei Zaharia, Mosharaf Chowdhury, Tathagata Das, Ankur Dave, Justin Ma, Murphy McCauley, Michael Franklin, Scott Shenker, Ion Stoica. Resilient Distributed Datasets: A Fault-Tolerant Abstraction for In-Memory Cluster Computing. Proceedings of the USENIX Symposium of Networked Systems Design and Implementation, 2012."

# %% [markdown]
# ## 1. Spark using RDDs
#
# Suppose we would like to analyse a huge log file, for instance a search engine's query log. The following line reads the contents of the file `log.txt` into a RDD (Resilient Distributed Dataset).

# %%
# necessary prolog
from pyspark import SparkContext
sc = SparkContext()
lines = sc.textFile("log.txt")

# %%
lines = sc.textFile("log.txt")

# %% [markdown]
# > NB We called the variable `spark` in the paper by Zahari et al. (2012) `sc` in our case (for 'Spark context').
# >
# > Note that the paper uses Scala examples, not Python.
#
# An RDD is a read-only collection of records that may be partitioned over many machines in your cluster. RDDs can only be created from other RDDs through a limited number of operations called _transformations_ (they may also be read from the distributed file system). Table 2 of Zahari et al. (2012) contains 13 transformations of RDDs. Why these transformations? Together these transformations support many algorithms, and, the transformations can be executed efficiently in parallel on clusters of machines.
#
# As an example of a transformation, `map()` takes as input a function, and applies this function to each record in the RDD. The functions that may be provided to map may not have any _side effects_, that is, they may input a record of the RDD and output a transformed record, but they cannot read or write files, nor can they have an internal state that is updated. If functions without side effects are used, then each machine in a large cluster can perform the function on part of the data without needing to know anything about results from the other machines on other parts of the data. As an example, take the following function that takes a line and outputs the line with all letters put to lower case:
#
#     lambda line: line.lower()
#
# This is called an _lambda_ function in Python. Lambda functions are anonymous functions because they have no name. The paper uses Scala syntax for anonymous functions, i.e. `line => line.toLowerCase()`.

# %%
lowerLines = lines.map(lambda line: line.lower())
lowerLines.collect()
# Out:
# ['info\t2016-12-05 18:00:00\tnl.utwente.santa\theerlijk avondje is gekomen',
#  'info\t2016-12-05 18:00:01\tnl.utwente.santa\tavondje van santa',
#  'info\t2016-12-05 18:00:02\tnl.utwente.santa\tvol verwachting klopt ons hart',
#  'warn\t2016-12-05 18:00:03\tnl.utwente.santa\twarning wie de roe krijgt wie de gard',
#  'info\t2016-12-05 18:00:04\tnl.utwente.santa\tvol verwachting klopt ons hart',
#  'warn\t2016-12-05 18:00:06\tnl.utwente.santa\twarning wie de roe krijgt wie de gard',
#  'info\t2016-12-05 18:00:07\tnl.utwente.santa\tsinging approved by saint nicolas',
#  'error\t2016-12-05 18:00:08\tnl.utwente.santa\terror fire place on aborting chimney descend',
#  'warn\t2016-12-05 18:00:09\tnl.utwente.santa\twarning rollback presents',
#  'info\t2016-12-05 18:01:00\tnl.utwente.santa\theerlijk avondje is gekomen',
#  'info\t2016-12-05 18:01:01\tnl.utwente.santa\tavondje van santa',
#  'info\t2016-12-05 18:01:02\tnl.utwente.santa\tvol verwachting klopt ons hart',
#  'warn\t2016-12-05 18:01:03\tnl.utwente.santa\twarning wie de roe krijgt wie de gard',
#  'info\t2016-12-05 18:01:04\tnl.utwente.santa\tvol verwachting klopt ons hart',
#  'warn\t2016-12-05 18:01:05\tnl.utwente.santa\twarning wie de roe krijgt wie de gard',
#  'info\t2016-12-05 18:01:05\tnl.utwente.santa\tsinging approved by saint nicolas',
#  'error\t2016-12-05 18:01:06\tnl.utwente.santa\terror fire place on aborting chimney descend',
#  'error\t2016-12-05 18:01:06\tnl.utwente.santa\terror retry chimney descend failed',
#  'warn\t2016-12-05 18:01:07\tnl.utwente.santa\twarning rollback presents',
#  'error\t2016-12-05 18:00:08\tnl.utwente.santa\terror fatal error shutting down',
#  'info\t2016-12-05 18:00:09\tnl.utwente.santa\tshutting down santaavond',
#  'info\t2016-12-05 18:00:12\tnl.utwente.santa\tbye']

# %% [markdown]
# Anonymous functions are a consice way to use a function once (maybe they should have been called _disposable functions_). The same line with a named function would be:
#
#
#     def toLower(line):
#         return line.lower()
#
#     lowerLines2 = lines.map(toLower)
#
# Spark runs all your operations on RDDs in parallel. If you want to do something in linear order in plain old Python, for instance outputting the contents of the RDD, then the function `collect()` turns your RDD into an ordinary Python array.
#
# > NB Beware, the Jupyter notebook might only show part of your result.
#
# > The `\t` strings in the output denote tabs in the original file.

# %%
lines.collect()
# Out:
# ['INFO\t2016-12-05 18:00:00\tnl.utwente.santa\tHeerlijk avondje is gekomen',
#  'INFO\t2016-12-05 18:00:01\tnl.utwente.santa\tAvondje van santa',
#  'INFO\t2016-12-05 18:00:02\tnl.utwente.santa\tVol verwachting klopt ons hart',
#  'WARN\t2016-12-05 18:00:03\tnl.utwente.santa\tWarning Wie de roe krijgt wie de gard',
#  'INFO\t2016-12-05 18:00:04\tnl.utwente.santa\tVol verwachting klopt ons hart',
#  'WARN\t2016-12-05 18:00:06\tnl.utwente.santa\tWarning Wie de roe krijgt wie de gard',
#  'INFO\t2016-12-05 18:00:07\tnl.utwente.santa\tSinging approved by Saint Nicolas',
#  'ERROR\t2016-12-05 18:00:08\tnl.utwente.santa\tError Fire place on Aborting chimney descend',
#  'WARN\t2016-12-05 18:00:09\tnl.utwente.santa\tWarning Rollback presents',
#  'INFO\t2016-12-05 18:01:00\tnl.utwente.santa\tHeerlijk avondje is gekomen',
#  'INFO\t2016-12-05 18:01:01\tnl.utwente.santa\tAvondje van santa',
#  'INFO\t2016-12-05 18:01:02\tnl.utwente.santa\tVol verwachting klopt ons hart',
#  'WARN\t2016-12-05 18:01:03\tnl.utwente.santa\tWarning Wie de roe krijgt wie de gard',
#  'INFO\t2016-12-05 18:01:04\tnl.utwente.santa\tVol verwachting klopt ons hart',
#  'WARN\t2016-12-05 18:01:05\tnl.utwente.santa\tWarning Wie de roe krijgt wie de gard',
#  'INFO\t2016-12-05 18:01:05\tnl.utwente.santa\tSinging approved by Saint Nicolas',
#  'ERROR\t2016-12-05 18:01:06\tnl.utwente.santa\tError Fire place on Aborting chimney descend',
#  'ERROR\t2016-12-05 18:01:06\tnl.utwente.santa\tError Retry chimney descend failed',
#  'WARN\t2016-12-05 18:01:07\tnl.utwente.santa\tWarning Rollback presents',
#  'ERROR\t2016-12-05 18:00:08\tnl.utwente.santa\tError Fatal error Shutting down',
#  'INFO\t2016-12-05 18:00:09\tnl.utwente.santa\tShutting down santaavond',
#  'INFO\t2016-12-05 18:00:12\tnl.utwente.santa\tBye']

# %% [markdown]
# ### Exercise 1.1, count the number of errors in the log
#
# Follow the examples from Zaharia et al. (2012), and print the number of lines that start with "ERROR". Your solution should print: 4.
#
#
# > Comments in Python are preceded by a hash `'#'`
#
# > To divide a long statement over multiple lines in Python, end a line with a backslah `'\'`.

# %%
# INSERT ANSWER HERE
# END ANSWER
errors = lines.filter(lambda w: w.startswith("ERROR"))
errors.count()
# Out:
# 4

# %% [markdown]
# c### Exercise 1.2, count errors mentioning chimney
#
# Follow the examples from Zaharia et al. (2012), and print the number of lines that start with "ERROR" and that contain "chimney". Your solution should print: 3. Tip: you might build on the result of the previous question.

# %%
# INSERT ANSWER HERE
# END ANSWER
results = errors.filter(lambda w: "chimney" in w)
results.collect()
# Out:
# ['ERROR\t2016-12-05 18:00:08\tnl.utwente.santa\tError Fire place on Aborting chimney descend',
#  'ERROR\t2016-12-05 18:01:06\tnl.utwente.santa\tError Fire place on Aborting chimney descend',
#  'ERROR\t2016-12-05 18:01:06\tnl.utwente.santa\tError Retry chimney descend failed']

# %% [markdown]
# ### Exercise 1.3, return the time fields of the errors mentioning 'chimney'
#
# Follow the examples from Zaharia et al. (2012), and print the time fields of the lines that start with "ERROR" and that contain "chimney". Your solution should print: `2016-12-05 18:00:08, 2016-12-05 18:01:06,` and `2016-12-05 18:01:06`.

# %%
# INSERT ANSWER HERE
# END ANSWER
results.map(lambda w: (w.split('\t')[1])).collect()
# Out:
# ['2016-12-05 18:00:08', '2016-12-05 18:01:06', '2016-12-05 18:01:06']

# %% [markdown]
# ### Exercise 1.4, the seminal MapReduce word count
#
# In 2004, Google employees Jeff Dean and Sanjay Ghemawat proposed a framework for distributed data processing that supports only 2 transformations: `map()` and `reduce()`. They called their framework appropriately MapReduce ([Dean and Ghemawat 2004][1]).
#
# The seminal example they introduce in their paper is _word count_: Input a large text corpus, and output all words with for each word its count, i.e. the total number of times it occurs in the text corpus. A naive implementation might update a global data structure for each word that it encounters, adding 1 for the particular word. However, remember that we need functions *without* side effects to be able to distribute computations over many machines (so no updating a data structure!). Dean and Ghemawat therefore propose a solution that splits words and outputs pairs (_word_, 1) in the "map phase"; and then adds the 1's in the "reduce phase" (after the framework groups all data with the same together). Spark can process every MapReduce algorithm (and many more complex algorithms) using its transformations. Study the word count solution by Dean and Ghemawat, and come up with the equivalent Spark solution. See also the remarks by Zahari et al. (2012), for instance in Section 7.1.
#
# Execute _word count_ on the message fields of the lines that start with "ERROR". Your solution should find that the three most occurring words are "error", "descend" and "chimney", which occur respectively 5, 3 and 3 times.
#
# > Tip: build your solution one transformation at a time: Start from the lines that start with "ERROR", then take the message field, then split the (lower-cased) fields on space " " to get the words, then transform each word to (word, 1), etc. Test your solution after adding each transformation.
#
# [1]: http://research.google.com/archive/mapreduce-osdi04.pdf "Jeffrey Dean and Sanjay Ghemawat. MapReduce: Simplified Data Processing on Large Clusters, In Proceedings of the 6th Symposium on Operating System Design and Implementation (OSDI), 2004"

# %%
# INSERT ANSWER HERE
# END ANSWER
content = errors.map(lambda w: (w.split('\t')[3]))#.collect()
#content.collect()
#content.map(lambda x: (x.split(),1)).collect()

counts = content.flatMap(lambda line: line.split(" ")) \
             .map(lambda word: (word, 1)) \
             .reduceByKey(lambda a, b: a + b)
sortedcount = counts.sortBy(lambda x: x[1], False).collect()
sortedcount[0:3]
# Out:
# [('Error', 4), ('descend', 3), ('chimney', 3)]

# %% [markdown]
# ### Further exercises
#
# Zahari et al. (2012) cover two more elegant examples of iterative algorithms that can be efficiently processed by Spark: _logistic regression_, and Google's _PageRank_. Similar solutions exist using MapReduce, but they are less efficient, because MapReduce writes all intermediate data to disk for each iteration of the algorithm, whereas Spark tries to keep data in memory, if possible.

# %% [markdown]
# ## 2.  Spark using DataFrames
#
# In the following examples we use Spark with Dataframes. In Spark, a DataFrame is a distributed collection of data organized into _named_ columns. It is conceptually equivalent to a table in a relational database or a data frame in R/Python, but with the optimizations provided by RDDs under the hood. We base this part of the tutorial on the SIGMOD 2015 paper by ([Armbrust et al. 2015][2])
#
# Let's read some example data in a DataFrame using the standard environment variable `sqlContext`. We read data from a json file, because it is _self-describing_, that is, it contains the schema information needed for DataFrames (except for the table name).
#
# [2]: https://amplab.cs.berkeley.edu/wp-content/uploads/2015/03/SparkSQLSigmod2015.pdf "Michael Armbrust, Reynold S. Xin, Cheng Lian, Yin Huai, Davies Liu, Joseph K. Bradley, Xiangrui Meng, Tomer Kaftan, Michael J. Franklin, Ali Ghodsi, Matei Zaharia. In. Proceedings of the International Conference on Management of Data (SIGMOD), 2015"

# %%
# neceesary prolog for dataframes
from pyspark import sql
sqlContext = sql.SQLContext(sc)

# %%
people = sqlContext.read.json("people.json") 

people.printSchema()
people.show()
# Out:
# root
#  |-- gender: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- organization: string (nullable = true)
#
# +------+---------+------------+
# |gender|     name|organization|
# +------+---------+------------+
# |  male|    Arjen|          RU|
# |  male|   Djoerd|          UT|
# |  male|    Robin|          UT|
# |  male|     Yuri|          UT|
# |female|    Doina|          UT|
# |female|     Anna|          UT|
# |  male|     Piet|         CBS|
# |  male|  Barteld|         CBS|
# |female|Jacobiene|         CBS|
# |  male|    Marco|         CBS|
# |female|  Claudia|         TUD|
# +------+---------+------------+

# %% [markdown]
# DataFrames support special functions like `printSchema()` and `show()` and the common [relational algebra operations](https://en.wikipedia.org/wiki/Relational_algebra): projection, called `select()`; selection, called `where()`; and join, called `join()`, as well as aggregations: (`groupBy()` and `agg()`).
#
# > Yes, you are right: Someone really messed up naming the relational algebra operations! The naming of relational algebra operations differs in some unfortunate ways from the naming used in SQL statements. The Spark algebra operations use the SQL conventions, to make the confusion complete.
#
# So, like RDDs, DataFrames support a limited number of transformations (but now based on relational algebra), and that's what we will have to work with. However, we might also work directly in SQL (see Exercise 2.4 below).

# %% [markdown]
# ### Exercise 2.1, select all names
#
# Show the list of names of all people (the projection of the column 'name').

# %%
# INSERT ANSWER HERE
people.select(people.name).show()
# Out:
# +---------+
# |     name|
# +---------+
# |    Arjen|
# |   Djoerd|
# |    Robin|
# |     Yuri|
# |    Doina|
# |     Anna|
# |     Piet|
# |  Barteld|
# |Jacobiene|
# |    Marco|
# |  Claudia|
# +---------+

# %% [markdown]
# ### Exercise 2.2, select all names of people from CBS
#
# Show the list of names of people that work at CBS (Can we first do the projection of the column 'name' and then the selection of the row for which `organization="CBS"`?).

# %%
# INSERT ANSWER HERE
# END ANSWER
people.show()
people.where(people.organization=="CBS").select(people.name).show()
# Out:
# +------+---------+------------+
# |gender|     name|organization|
# +------+---------+------------+
# |  male|    Arjen|          RU|
# |  male|   Djoerd|          UT|
# |  male|    Robin|          UT|
# |  male|     Yuri|          UT|
# |female|    Doina|          UT|
# |female|     Anna|          UT|
# |  male|     Piet|         CBS|
# |  male|  Barteld|         CBS|
# |female|Jacobiene|         CBS|
# |  male|    Marco|         CBS|
# |female|  Claudia|         TUD|
# +------+---------+------------+
#
# +---------+
# |     name|
# +---------+
# |     Piet|
# |  Barteld|
# |Jacobiene|
# |    Marco|
# +---------+

# %% [markdown]
# ----
#
# Let's introduce the following organization DataFrame. Interestingly, this DataFrame contains two structured columns, a feature known from object-relational databases.

# %%
organizations = sqlContext.read.json("organizations.json") 
organizations.printSchema()
organizations.show()
# Out:
# root
#  |-- address: struct (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- number: long (nullable = true)
#  |    |-- street: string (nullable = true)
#  |-- attractions: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- color: string (nullable = true)
#  |-- organization: string (nullable = true)
#
# +--------------------+--------------------+-----+------------+
# |             address|         attractions|color|organization|
# +--------------------+--------------------+-----+------------+
# |[Enschede,5,drien...|[torentje, hadoop...|black|          UT|
# |[Heerlen,11,CBS-weg]|[mijnmuseum, spar...| blue|         CBS|
# |[Nijmegen,4,Comen...|       [doornroosje]|  red|          RU|
# |   [Delft,5,Postbus]|      [nice cluster]| blue|         TUD|
# +--------------------+--------------------+-----+------------+

# %% [markdown]
# ### Exercise 2.3, people in blue organizations
#
# Show the name and organization of people whose organization's color is blue by joining the two tables.
#
# > Question: Can we speed up the computation by changing the order of the statements?
#
# > Bonus: Count for each organization the number of people, outputting ("organization", "count"). Note that the Armbrust et al. paper contains an error in Section 3.3: the operation `.agg(count("name"))` should be `.count()`.

# %%
# INSERT ANSWER HERE
# END ANSWER
org = organizations.where(organizations.color=="blue").select(organizations.organization)
people.where(people.organization in org).show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-f9f36006b7f1> in <module>()
#       2 # END ANSWER
#       3 org = organizations.where(organizations.color=="blue").select(organizations.organization)
# ----> 4 people.where(people.organization in org).show()
#
# /usr/local/spark/python/pyspark/sql/column.py in __nonzero__(self)
#     445
#     446     def __nonzero__(self):
# --> 447         raise ValueError("Cannot convert column into bool: please use '&' for 'and', '|' for 'or', "
#     448                          "'~' for 'not' when building DataFrame boolean expressions.")
#     449     __bool__ = __nonzero__
#
# ValueError: Cannot convert column into bool: please use '&' for 'and', '|' for 'or', '~' for 'not' when building DataFrame boolean expressions.

# %% [markdown]
# ----
#
# If you are familiar with SQL, then the following approach would also find the people with blue organizations. Once we registered the DataFrames `people` and `organizations`, we can use `sqlContext.sql()` to execute any SQL query.

# %%
people.registerTempTable("people");
organizations.registerTempTable("organizations");
sqlContext.sql('''
SELECT P.name, O.organization
FROM people P, organizations O
WHERE P.organization = O.organization
AND O.color = 'blue'
''').show()
# Out:
# +---------+------------+
# |     name|organization|
# +---------+------------+
# |     Piet|         CBS|
# |  Barteld|         CBS|
# |Jacobiene|         CBS|
# |    Marco|         CBS|
# |  Claudia|         TUD|
# +---------+------------+

# %% [markdown]
# ### Exercise 2.4, women from Enschede
#
# In SQL, the complex types `address` and `attractions` are available as follows: For instance, `Organizations.address.city = 'Heerlen'` for organizations in Heerlen.
# Count the number of female employees in Enschede. Your answer should be: 2.

# %%
# INSERT ANSWER HERE
# END ANSWER
sqlContext.sql('''
SELECT P.name, O.organization, O.address.city
FROM people P, organizations O
WHERE O.address.city = 'Enschede'
AND P.organization = O.organization
AND P.gender = 'female'
''').show()
# Out:
# +-----+------------+--------+
# | name|organization|    city|
# +-----+------------+--------+
# |Doina|          UT|Enschede|
# | Anna|          UT|Enschede|
# +-----+------------+--------+

# %% [markdown]
# ### Further exercises
#
# New to SQL? Then we recommend additional SQL exercises, for instance [Learn SQL from Codecademy](https://www.codecademy.com/learn/learn-sql).

# %% [markdown]
# ## 3.  DataCamp sample data
#
# Below you find a samples of the data that is available on the DataCamp Hadoop/Spark cluster. Use the sample data to develop and test your Spark scripts before executing them on the cluster.
#
#
# ### Dutch Tweets
# We use the Twitter data described by ([Tjong-Kim-Sang and Van den Bosch 2013][3]) which is available on the Twente Hadoop cluster under: `/data/twitterNL`.
#
# [3]: http://ifarm.nl/erikt/papers/clin2013.pdf "Erik Tjong Kim Sang and Antal van den Bosch. Dealing with big data: The case of Twitter. In: Computational Linguistics in the Netherlands Journal 3, ISSN: 2211-4009, pages 121-134, 2013."

# %%
tweets = sqlContext.read.json("tweets.json.gz") 

# uncomment to print the (crazy) schema:
# tweets.printSchema()

tweets.select("text").show(10)
# Out:
# +--------------------+
# |                text|
# +--------------------+
# |Pinnen over je wa...|
# |@AllesofNooit @He...|
# |#dooba #sexdate J...|
# |En weer een uur v...|
# |Frederik Meulewae...|
# |#webcambabes patr...|
# |Weer een kwartier...|
# |Een hond als huis...|
# |Het gebaar van de...|
# |[NOS] Politie zet...|
# +--------------------+
# only showing top 10 rows

# %% [markdown]
# ### AIS data
#
# The [Automatic identification system](https://en.wikipedia.org/wiki/Automatic_identification_system) (AIS) is an automatic tracking system used on ships and by vessel traffic services (VTS) for identifying and locating vessels by electronically exchanging data with other nearby ships, AIS base stations, and satellites. The data is available on the Twente Hadoop cluster under: `/data/aisUT`.

# %%
ais = sqlContext.read.json("ais.json.gz") 
# ais.show(5)
ais.printSchema()
# Out:
# root
#  |-- callsign: string (nullable = true)
#  |-- cog: long (nullable = true)
#  |-- destination: string (nullable = true)
#  |-- dimbow: long (nullable = true)
#  |-- dimport: long (nullable = true)
#  |-- dimstarboard: long (nullable = true)
#  |-- dimstern: long (nullable = true)
#  |-- draught: long (nullable = true)
#  |-- eta_day: long (nullable = true)
#  |-- eta_hour: long (nullable = true)
#  |-- eta_minute: long (nullable = true)
#  |-- eta_month: long (nullable = true)
#  |-- heading: long (nullable = true)
#  |-- imo: long (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- lat2: string (nullable = true)
#  |-- lon: double (nullable = true)
#  |-- lon2: string (nullable = true)
#  |-- mmsi: long (nullable = true)
#  |-- nav_status: long (nullable = true)
#  |-- rot_angle: double (nullable = true)
#  |-- rot_direction: string (nullable = true)
#  |-- shipname: string (nullable = true)
#  |-- shiptype: long (nullable = true)
#  |-- sog: long (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- type: long (nullable = true)

# %% [markdown]
# ### RDW data
# The Rijksdienst Wegverkeer is the Dutch ministery the takes care of the public roads. The data contains measurements from sensors in the roads. This data is available as comma-separated value (CSV) files and is available on the Twente Hadoop cluster under: `/data/cbs/loopraw`.

# %%
rdw = sc.textFile("rdw.csv.gz")
rdw.map(lambda line: line.split(',')[:3]).collect()
# Out:
# [['RWS01_MONIBAS_0091hrl0763ra', '1', '11B'],
#  ['RWS01_MONIBAS_0091hrl0763ra', '1', '12B'],
#  ['RWS01_MONIBAS_0091hrl0785ra', '1', '1B'],
#  ['RWS01_MONIBAS_0091hrl0785ra', '1', '2B'],
#  ['RWS01_MONIBAS_0091hrl0785ra', '1', '3B'],
#  ['RWS01_MONIBAS_0091hrl0785ra', '1', '4B'],
#  ['RWS01_MONIBAS_0091hrl0785ra', '1', '9B'],
#  ['RWS01_MONIBAS_0091hrl0785ra', '1', '10B'],
#  ['RWS01_MONIBAS_0091hrl0785ra', '1', '11B'],
#  ['RWS01_MONIBAS_0091hrl0785ra', '1', '12B'],
#  ['RWS01_MONIBAS_0091hrl0794ra', '1', '1B'],
#  ['RWS01_MONIBAS_0091hrl0794ra', '1', '2B'],
#  ['RWS01_MONIBAS_0091hrl0794ra', '1', '3B'],
#  ['RWS01_MONIBAS_0091hrl0794ra', '1', '4B'],
#  ['RWS01_MONIBAS_0091hrl0794ra', '1', '9B'],
#  ['RWS01_MONIBAS_0091hrl0794ra', '1', '10B'],
#  ['RWS01_MONIBAS_0091hrl0794ra', '1', '11B'],
#  ['RWS01_MONIBAS_0091hrl0794ra', '1', '12B'],
#  ['RWS01_MONIBAS_0091hrr0059ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0059ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0059ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0064ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0064ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0064ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0068ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0068ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0068ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0073ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0073ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0073ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0077ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0077ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0077ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0078ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0078ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0078ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0080ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0080ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0080ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0080ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0082ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0082ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0082ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0082ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0086ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0086ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0086ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0091ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0091ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0091ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0096ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0096ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0096ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0096ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0100ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0100ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0100ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0100ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0103ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0103ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0103ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0103ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0105ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0105ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0110ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0110ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0110ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0112ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0112ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0112ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0117ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0117ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0230ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0230ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0235ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0235ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0235ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0235ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0241ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0241ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0241ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0247ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0247ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0247ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0253ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0253ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0253ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0259ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0259ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0259ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0262ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0262ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0262ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0267ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0267ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0267ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0268ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0268ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0268ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0272ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0272ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0272ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0272ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0278ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0278ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0278ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0278ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0282ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0282ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0282ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0282ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0287ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0287ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0287ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0293ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0293ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0293ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0297ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0297ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0297ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0302ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0302ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0302ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0308ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0308ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0308ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0313ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0313ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0313ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0318ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0318ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0318ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0322ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0322ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0322ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0326ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0326ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0326ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0326ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0328ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0328ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0328ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0328ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0331ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0331ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0331rb', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0331rb', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0333ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0333ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0339ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0339ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0344ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0344ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0350ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0350ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0350ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0353ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0353ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0353ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0356ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0356ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0356ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0362ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0362ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0362ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0363ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0363ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0367ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0367ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0367ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0371ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0371ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0373ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0373ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0373ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0377ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0377ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0377ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0381ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0381ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0381ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0384ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0384ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0384ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0388ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0388ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0388ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0391ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0391ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0391ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0394ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0394ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0394ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0396ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0396ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0396ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0399ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0399ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0399ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0401ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0401ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0401ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0401ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0401ra', '1', '9A'],
#  ['RWS01_MONIBAS_0091hrr0405ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0405ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0405ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0405ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0405ra', '1', '9A'],
#  ['RWS01_MONIBAS_0091hrr0408ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0408ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0408ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0410ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0410ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0411ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0411ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0411ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0414ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0414ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0414ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0418ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0418ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0418ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0421ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0421ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0421ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0421ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0423ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0423ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0423ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0423ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0423rb', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0427ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0427ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0427ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0433ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0433ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0433ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0437ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0437ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0437ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0439ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0439ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0439ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0443ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0443ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0443ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0448ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0448ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0448ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0453ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0453ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0453ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0456ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0456ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0456ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0458ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0458ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0458ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0459ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0459ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0462ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0462ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0462ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0467ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0467ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0467ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0469ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0469ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0469ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0473ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0473ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0473ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0476ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0476ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0476ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0478ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0478ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0478ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0479ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0479ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0481ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0481ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0481ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0482ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0482ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0484ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0484ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0484ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0485ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0485ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0488ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0488ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0488ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0493ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0493ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0493rb', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0493rb', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0496ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0496ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0500ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0500ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0504ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0504ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0507ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0507ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0509ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0509ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0512ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0512ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0514ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0514ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0517ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0517ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0518ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0518ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0521ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0521ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0521rb', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0521rb', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0521rc', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0521rc', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0521rc', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0525ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0525ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0525ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0528ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0528ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0528ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0532ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0532ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0532ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0539ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0539ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0546ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0546ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0551ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0551ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0555ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0555ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0559ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0559ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0559ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0559ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0562ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0562ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0562ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0562ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0566ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0566ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0566ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0572ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0572ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0572ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0575ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0575ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0575ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0575ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0577ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0577ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0577ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0577ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0580ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0580ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0580ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0584ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0584ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0584ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0584ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0588ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0588ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0588ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0588ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0592ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0592ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0592ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0598ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0598ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0598ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0598ra', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0601ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0601ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0601ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0602ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0602ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0604ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0604ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0604ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0607ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0607ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0610ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0610ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0610ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0616ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0616ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0616ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0621ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0621ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0621ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0625ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0625ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0625ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0631ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0631ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0631ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0634ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0634ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0636ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0636ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0636ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0639ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0639ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0639ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0642ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0642ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0642ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0645ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0645ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0645ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0648ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0648ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0648ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0651ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0651ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0651ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0654ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0654ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0654ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0657ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0657ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0657ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0658ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0658ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0660ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0660ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0660ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0663ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0663ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0663ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0664ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0664ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0666ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0666ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0666ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0669ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0669ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0669ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0670ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0670ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0672ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0672ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0672ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0675ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0675ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0675ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0676ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0676ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0678ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0678ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0678ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0679ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0679ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0683ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0683ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0683ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0686ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0686ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0686ra', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0687ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0687ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0692ra', '1', '1A'],
#  ['RWS01_MONIBAS_0091hrr0692ra', '1', '3A'],
#  ['RWS01_MONIBAS_0091hrr0692rb', '1', '5A'],
#  ['RWS01_MONIBAS_0091hrr0692rb', '1', '7A'],
#  ['RWS01_MONIBAS_0091hrr0697ra', '1', '1B'],
#  ['RWS01_MONIBAS_0091hrr0697ra', '1', '2B'],
#  ['RWS01_MONIBAS_0091hrr0697ra', '1', '3B'],
#  ['RWS01_MONIBAS_0091hrr0697ra', '1', '4B'],
#  ['RWS01_MONIBAS_0091hrr0697ra', '1', '9B'],
#  ['RWS01_MONIBAS_0091hrr0697ra', '1', '10B'],
#  ['RWS01_MONIBAS_0091hrr0697ra', '1', '11B'],
#  ['RWS01_MONIBAS_0091hrr0697ra', '1', '12B'],
#  ['RWS01_MONIBAS_0091hrr0759ra', '1', '1B'],
#  ['RWS01_MONIBAS_0091hrr0759ra', '1', '2B'],
#  ['RWS01_MONIBAS_0091hrr0759ra', '1', '3B'],
#  ['RWS01_MONIBAS_0091hrr0759ra', '1', '4B'],
#  ['RWS01_MONIBAS_0091hrr0759ra', '1', '9B'],
#  ['RWS01_MONIBAS_0091hrr0759ra', '1', '10B'],
#  ['RWS01_MONIBAS_0091hrr0759ra', '1', '11B'],
#  ['RWS01_MONIBAS_0091hrr0759ra', '1', '12B'],
#  ['RWS01_MONIBAS_0091hrr0763ra', '1', '1B'],
#  ['RWS01_MONIBAS_0091hrr0763ra', '1', '2B'],
#  ['RWS01_MONIBAS_0091hrr0763ra', '1', '3B'],
#  ['RWS01_MONIBAS_0091hrr0763ra', '1', '4B'],
#  ['RWS01_MONIBAS_0091hrr0763ra', '1', '9B'],
#  ['RWS01_MONIBAS_0091hrr0763ra', '1', '10B'],
#  ['RWS01_MONIBAS_0091hrr0763ra', '1', '11B'],
#  ['RWS01_MONIBAS_0091hrr0763ra', '1', '12B'],
#  ['RWS01_MONIBAS_0091hrr0785ra', '1', '1B'],
#  ['RWS01_MONIBAS_0091hrr0785ra', '1', '2B'],
#  ['RWS01_MONIBAS_0091hrr0785ra', '1', '3B'],
#  ['RWS01_MONIBAS_0091hrr0785ra', '1', '4B'],
#  ['RWS01_MONIBAS_0091hrr0785ra', '1', '9B'],
#  ['RWS01_MONIBAS_0091hrr0785ra', '1', '10B'],
#  ['RWS01_MONIBAS_0091hrr0785ra', '1', '11B'],
#  ['RWS01_MONIBAS_0091hrr0785ra', '1', '12B'],
#  ['RWS01_MONIBAS_0091hrr0795ra', '1', '1B'],
#  ['RWS01_MONIBAS_0091hrr0795ra', '1', '2B'],
#  ['RWS01_MONIBAS_0091hrr0795ra', '1', '3B'],
#  ['RWS01_MONIBAS_0091hrr0795ra', '1', '4B'],
#  ['RWS01_MONIBAS_0091hrr0795ra', '1', '9B'],
#  ['RWS01_MONIBAS_0091hrr0795ra', '1', '10B'],
#  ['RWS01_MONIBAS_0091hrr0795ra', '1', '11B'],
#  ['RWS01_MONIBAS_0091hrr0795ra', '1', '12B'],
#  ['RWS01_MONICA_00D00900B400D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00900B400D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00900B400D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00900B400D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00900C80090200005', '1', '1B'],
#  ['RWS01_MONICA_00D00900C80090200005', '1', '2B'],
#  ['RWS01_MONICA_00D00900C80090200005', '1', '3B'],
#  ['RWS01_MONICA_00D00900C80090200005', '1', '4B'],
#  ['RWS01_MONICA_00D00900C80090200009', '1', '9B'],
#  ['RWS01_MONICA_00D00900C80090200009', '1', '10B'],
#  ['RWS01_MONICA_00D00900C80090200009', '1', '11B'],
#  ['RWS01_MONICA_00D00900C80090200009', '1', '12B'],
#  ['RWS01_MONICA_00D00905780FD0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00905780FD0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00905780FD0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00905780FD0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00905780FD0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00905780FD0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00905780FD0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00905780FD0050009', '1', '12B'],
#  ['RWS01_MONICA_00D009057815D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D009057815D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D009057815D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D009057815D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D009057815D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D009057815D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D009057815D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D009057815D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D009057815D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D009057815D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D009057815D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D009057815D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D00905A800D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00905A800D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00905A800D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00905A800D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00905A800D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00905A800D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00905A800D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00905A800D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00905A800D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00905A800D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00905A800D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00905A800D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00905A800D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00905A800D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00905A800D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00905A800D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00905A800D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00905A800D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00905A800D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00905A800D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D00905B80018200005', '1', '1B'],
#  ['RWS01_MONICA_00D00905B80018200005', '1', '2B'],
#  ['RWS01_MONICA_00D00905B80018200005', '1', '3B'],
#  ['RWS01_MONICA_00D00905B80018200005', '1', '4B'],
#  ['RWS01_MONICA_00D00905BC0000200007', '1', '1B'],
#  ['RWS01_MONICA_00D00905BC0000200007', '1', '2B'],
#  ['RWS01_MONICA_00D00905BC0000200007', '1', '3B'],
#  ['RWS01_MONICA_00D00905BC0000200007', '1', '4B'],
#  ['RWS01_MONICA_00D00905BC00D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00905BC00D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00905BC00D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00905BC00D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00905BC00D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00905BC00D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00905BC00D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00905BC00D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00905BC08D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00905BC08D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00905BC08D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00905BC08D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00905BC08D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00905BC08D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00905BC08D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00905BC08D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00905BC08D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00905BC08D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00905BC08D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00905BC08D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D00905C42310200005', '1', '1B'],
#  ['RWS01_MONICA_00D00905C42310200005', '1', '2B'],
#  ['RWS01_MONICA_00D00905C42310200005', '1', '3B'],
#  ['RWS01_MONICA_00D00905C42310200005', '1', '4B'],
#  ['RWS01_MONICA_00D00905C823D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00905C823D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00905C823D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00905C823D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00905C823D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00905C823D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00905C823D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00905C823D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00905CC3CD0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00905CC3CD0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00905CC3CD0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00905CC3CD0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00905CC3CD0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00905CC3CD0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00905CC3CD0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00905CC3CD0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00905D432D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00905D432D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00905D432D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00905D432D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00905D432D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00905D432D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00905D432D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00905D432D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00905D432D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00905D432D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00905D432D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00905D432D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D00905D82DD0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00905D82DD0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00905D82DD0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00905D82DD0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00905D82DD0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00905D82DD0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00905D82DD0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00905D82DD0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00905D82DD0050305', '1', '1B'],
#  ['RWS01_MONICA_00D00905D82DD0050305', '1', '2B'],
#  ['RWS01_MONICA_00D00905D82DD0050305', '1', '3B'],
#  ['RWS01_MONICA_00D00905D82DD0050305', '1', '4B'],
#  ['RWS01_MONICA_00D00905EC14C0200005', '1', '1B'],
#  ['RWS01_MONICA_00D00905EC14C0200005', '1', '2B'],
#  ['RWS01_MONICA_00D00905EC14C0200005', '1', '3B'],
#  ['RWS01_MONICA_00D00905EC14C0200005', '1', '4B'],
#  ['RWS01_MONICA_00D00905EC14D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00905EC14D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00905EC14D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00905EC14D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00905EC14D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00905EC14D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00905EC14D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00905EC14D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00905F400A8200007', '1', '1B'],
#  ['RWS01_MONICA_00D00905F400A8200007', '1', '2B'],
#  ['RWS01_MONICA_00D00905F400A8200007', '1', '3B'],
#  ['RWS01_MONICA_00D00905F400A8200007', '1', '4B'],
#  ['RWS01_MONICA_00D00905F400D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00905F400D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00905F400D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00905F400D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00905F400D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00905F400D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00905F400D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00905F400D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00905F400D007000F', '1', '17B'],
#  ['RWS01_MONICA_00D00905F400D007000F', '1', '18B'],
#  ['RWS01_MONICA_00D00905F400D007000F', '1', '19B'],
#  ['RWS01_MONICA_00D00905F400D007000F', '1', '20B'],
#  ['RWS01_MONICA_00D00905F400D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00905F400D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00905F400D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00905F400D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D009060000D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D009060000D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D009060000D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D009060000D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D009060000D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D009060000D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D009060000D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D009060000D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D009062C00C0200005', '1', '1B'],
#  ['RWS01_MONICA_00D009062C00C0200005', '1', '2B'],
#  ['RWS01_MONICA_00D009062C00C0200005', '1', '3B'],
#  ['RWS01_MONICA_00D009062C00C0200005', '1', '4B'],
#  ['RWS01_MONICA_00D009062C00C0200009', '1', '9B'],
#  ['RWS01_MONICA_00D009062C00C0200009', '1', '10B'],
#  ['RWS01_MONICA_00D009062C00C0200009', '1', '11B'],
#  ['RWS01_MONICA_00D009062C00C0200009', '1', '12B'],
#  ['RWS01_MONICA_00D009063C00D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D009063C00D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D009063C00D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D009063C00D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D009063C00D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D009063C00D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D009063C00D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D009063C00D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D009063C00D007000F', '1', '17B'],
#  ['RWS01_MONICA_00D009063C00D007000F', '1', '18B'],
#  ['RWS01_MONICA_00D009063C00D007000F', '1', '19B'],
#  ['RWS01_MONICA_00D009063C00D007000F', '1', '20B'],
#  ['RWS01_MONICA_00D00906685AD0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00906685AD0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00906685AD0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00906685AD0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00906685AD007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00906685AD007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00906685AD007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00906685AD007000B', '1', '12B'],
#  ['RWS01_MONICA_00D009066C0FD0050005', '1', '1B'],
#  ['RWS01_MONICA_00D009066C0FD0050005', '1', '2B'],
#  ['RWS01_MONICA_00D009066C0FD0050005', '1', '3B'],
#  ['RWS01_MONICA_00D009066C0FD0050005', '1', '4B'],
#  ['RWS01_MONICA_00D009066C0FD0050009', '1', '9B'],
#  ['RWS01_MONICA_00D009066C0FD0050009', '1', '10B'],
#  ['RWS01_MONICA_00D009066C0FD0050009', '1', '11B'],
#  ['RWS01_MONICA_00D009066C0FD0050009', '1', '12B'],
#  ['RWS01_MONICA_00D009066C0FD0050185', '1', '1B'],
#  ['RWS01_MONICA_00D009066C0FD0050185', '1', '2B'],
#  ['RWS01_MONICA_00D009066C0FD0050185', '1', '3B'],
#  ['RWS01_MONICA_00D009066C0FD0050185', '1', '4B'],
#  ['RWS01_MONICA_00D009067801D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D009067801D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D009067801D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D009067801D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D009067801D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D009067801D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D009067801D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D009067801D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D009067801D0050185', '1', '1B'],
#  ['RWS01_MONICA_00D009067801D0050185', '1', '2B'],
#  ['RWS01_MONICA_00D009067801D0050185', '1', '3B'],
#  ['RWS01_MONICA_00D009067801D0050185', '1', '4B'],
#  ['RWS01_MONICA_00D00906880AD0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00906880AD0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00906880AD0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00906880AD0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00906880AD007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00906880AD007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00906880AD007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00906880AD007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00906880AD0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00906880AD0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00906880AD0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00906880AD0070187', '1', '4B'],
#  ['RWS01_MONICA_00D009068852D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D009068852D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D009068852D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D009068852D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D009068852D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D009068852D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D009068852D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D009068852D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D009068852D0050305', '1', '1B'],
#  ['RWS01_MONICA_00D009068852D0050305', '1', '2B'],
#  ['RWS01_MONICA_00D009068852D0050305', '1', '3B'],
#  ['RWS01_MONICA_00D009068852D0050305', '1', '4B'],
#  ['RWS01_MONICA_00D009068852D0050309', '1', '9B'],
#  ['RWS01_MONICA_00D009068852D0050309', '1', '10B'],
#  ['RWS01_MONICA_00D009068852D0050309', '1', '11B'],
#  ['RWS01_MONICA_00D009068852D0050309', '1', '12B'],
#  ['RWS01_MONICA_00D00906A40A00200007', '1', '1B'],
#  ['RWS01_MONICA_00D00906A40A00200007', '1', '2B'],
#  ['RWS01_MONICA_00D00906A40A00200007', '1', '3B'],
#  ['RWS01_MONICA_00D00906A40A00200007', '1', '4B'],
#  ['RWS01_MONICA_00D00906A40AD0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00906A40AD0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00906A40AD0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00906A40AD0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00906A40AD0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00906A40AD0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00906A40AD0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00906A40AD0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00906A40AD0050185', '1', '1B'],
#  ['RWS01_MONICA_00D00906A40AD0050185', '1', '2B'],
#  ['RWS01_MONICA_00D00906A40AD0050185', '1', '3B'],
#  ['RWS01_MONICA_00D00906A40AD0050185', '1', '4B'],
#  ['RWS01_MONICA_00D00906AC50D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00906AC50D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00906AC50D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00906AC50D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00906AC50D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00906AC50D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00906AC50D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00906AC50D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00906AC50D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00906AC50D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00906AC50D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00906AC50D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D00906C40C08200007', '1', '1B'],
#  ['RWS01_MONICA_00D00906C40C08200007', '1', '2B'],
#  ['RWS01_MONICA_00D00906C40C08200007', '1', '3B'],
#  ['RWS01_MONICA_00D00906C40C08200007', '1', '4B'],
#  ['RWS01_MONICA_00D00906C40C10200005', '1', '1B'],
#  ['RWS01_MONICA_00D00906C40C10200005', '1', '2B'],
#  ['RWS01_MONICA_00D00906C40C10200005', '1', '3B'],
#  ['RWS01_MONICA_00D00906C40C10200005', '1', '4B'],
#  ['RWS01_MONICA_00D00906D423D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00906D423D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00906D423D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00906D423D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00906D423D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00906D423D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00906D423D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00906D423D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00906D423D0050305', '1', '1B'],
#  ['RWS01_MONICA_00D00906D423D0050305', '1', '2B'],
#  ['RWS01_MONICA_00D00906D423D0050305', '1', '3B'],
#  ['RWS01_MONICA_00D00906D423D0050305', '1', '4B'],
#  ['RWS01_MONICA_00D00906DC0AD0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00906DC0AD0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00906DC0AD0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00906DC0AD0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00906DC0AD007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00906DC0AD007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00906DC0AD007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00906DC0AD007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00906DC0AD0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00906DC0AD0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00906DC0AD0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00906DC0AD0070187', '1', '4B'],
#  ['RWS01_MONICA_00D009075400D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D009075400D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D009075400D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D009075400D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D009075400D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D009075400D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D009075400D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D009075400D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D009075400D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D009075400D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D009075400D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D009075400D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D009075C00D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D009075C00D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D009075C00D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D009075C00D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D009075C00D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D009075C00D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D009075C00D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D009075C00D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D009075C00D0050185', '1', '1B'],
#  ['RWS01_MONICA_00D009075C00D0050185', '1', '2B'],
#  ['RWS01_MONICA_00D009075C00D0050185', '1', '3B'],
#  ['RWS01_MONICA_00D009075C00D0050185', '1', '4B'],
#  ['RWS01_MONICA_00D009076415D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D009076415D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D009076415D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D009076415D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D009076415D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D009076415D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D009076415D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D009076415D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D009076415D0050185', '1', '1B'],
#  ['RWS01_MONICA_00D009076415D0050185', '1', '2B'],
#  ['RWS01_MONICA_00D009076415D0050185', '1', '3B'],
#  ['RWS01_MONICA_00D009076415D0050185', '1', '4B'],
#  ['RWS01_MONICA_00D009076415D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D009076415D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D009076415D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D009076415D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D009076415D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D009076415D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D009076415D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D009076415D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D009076415D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D009076415D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D009076415D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D009076415D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D00907A04ED0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00907A04ED0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00907A04ED0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00907A04ED0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00907A04ED007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00907A04ED007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00907A04ED007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00907A04ED007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00907A04ED0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00907A04ED0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00907A04ED0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00907A04ED0070187', '1', '4B'],
#  ['RWS01_MONICA_00D009095824D0050005', '1', '1B'],
#  ['RWS01_MONICA_00D009095824D0050005', '1', '2B'],
#  ['RWS01_MONICA_00D009095824D0050005', '1', '3B'],
#  ['RWS01_MONICA_00D009095824D0050005', '1', '4B'],
#  ['RWS01_MONICA_00D009095824D0050009', '1', '9B'],
#  ['RWS01_MONICA_00D009095824D0050009', '1', '10B'],
#  ['RWS01_MONICA_00D009095824D0050009', '1', '11B'],
#  ['RWS01_MONICA_00D009095824D0050009', '1', '12B'],
#  ['RWS01_MONICA_00D009095824D005000D', '1', '17B'],
#  ['RWS01_MONICA_00D009095824D005000D', '1', '18B'],
#  ['RWS01_MONICA_00D009095824D005000D', '1', '19B'],
#  ['RWS01_MONICA_00D009095824D005000D', '1', '20B'],
#  ['RWS01_MONICA_00D00909582ED0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00909582ED0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00909582ED0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00909582ED0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00909582ED007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00909582ED007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00909582ED007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00909582ED007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00909582ED007000F', '1', '17B'],
#  ['RWS01_MONICA_00D00909582ED007000F', '1', '18B'],
#  ['RWS01_MONICA_00D00909582ED007000F', '1', '19B'],
#  ['RWS01_MONICA_00D00909582ED007000F', '1', '20B'],
#  ['RWS01_MONICA_00D00909582ED0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00909582ED0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00909582ED0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00909582ED0070187', '1', '4B'],
#  ['RWS01_MONICA_00D00909881FD0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00909881FD0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00909881FD0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00909881FD0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00909881FD0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00909881FD0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00909881FD0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00909881FD0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00909881FD0050185', '1', '1B'],
#  ['RWS01_MONICA_00D00909881FD0050185', '1', '2B'],
#  ['RWS01_MONICA_00D00909881FD0050185', '1', '3B'],
#  ['RWS01_MONICA_00D00909881FD0050185', '1', '4B'],
#  ['RWS01_MONICA_00D009098829D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D009098829D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D009098829D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D009098829D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D009098829D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D009098829D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D009098829D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D009098829D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D009098829D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D009098829D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D009098829D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D009098829D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D00909A82818200005', '1', '1B'],
#  ['RWS01_MONICA_00D00909A82818200005', '1', '2B'],
#  ['RWS01_MONICA_00D00909A82818200005', '1', '3B'],
#  ['RWS01_MONICA_00D00909A82818200005', '1', '4B'],
#  ['RWS01_MONICA_00D00909A83DD0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00909A83DD0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00909A83DD0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00909A83DD0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00909A83DD0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00909A83DD0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00909A83DD0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00909A83DD0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00909A83DD0050185', '1', '1B'],
#  ['RWS01_MONICA_00D00909A83DD0050185', '1', '2B'],
#  ['RWS01_MONICA_00D00909A83DD0050185', '1', '3B'],
#  ['RWS01_MONICA_00D00909A83DD0050185', '1', '4B'],
#  ['RWS01_MONICA_00D00909AC0010200005', '1', '1B'],
#  ['RWS01_MONICA_00D00909AC0010200005', '1', '2B'],
#  ['RWS01_MONICA_00D00909AC0010200005', '1', '3B'],
#  ['RWS01_MONICA_00D00909AC0010200005', '1', '4B'],
#  ['RWS01_MONICA_00D00909C41900200007', '1', '1B'],
#  ['RWS01_MONICA_00D00909C41900200007', '1', '2B'],
#  ['RWS01_MONICA_00D00909C41900200007', '1', '3B'],
#  ['RWS01_MONICA_00D00909C41900200007', '1', '4B'],
#  ['RWS01_MONICA_00D00909C43CD0050005', '1', '1B'],
#  ['RWS01_MONICA_00D00909C43CD0050005', '1', '2B'],
#  ['RWS01_MONICA_00D00909C43CD0050005', '1', '3B'],
#  ['RWS01_MONICA_00D00909C43CD0050005', '1', '4B'],
#  ['RWS01_MONICA_00D00909C43CD0050009', '1', '9B'],
#  ['RWS01_MONICA_00D00909C43CD0050009', '1', '10B'],
#  ['RWS01_MONICA_00D00909C43CD0050009', '1', '11B'],
#  ['RWS01_MONICA_00D00909C43CD0050009', '1', '12B'],
#  ['RWS01_MONICA_00D00909C43CD0050185', '1', '1B'],
#  ['RWS01_MONICA_00D00909C43CD0050185', '1', '2B'],
#  ['RWS01_MONICA_00D00909C43CD0050185', '1', '3B'],
#  ['RWS01_MONICA_00D00909C43CD0050185', '1', '4B'],
#  ['RWS01_MONICA_00D00909C446D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00909C446D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00909C446D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00909C446D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00909C446D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00909C446D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00909C446D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00909C446D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00909C446D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00909C446D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00909C446D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00909C446D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D00909C45508200007', '1', '1B'],
#  ['RWS01_MONICA_00D00909C45508200007', '1', '2B'],
#  ['RWS01_MONICA_00D00909C45508200007', '1', '3B'],
#  ['RWS01_MONICA_00D00909C45508200007', '1', '4B'],
#  ['RWS01_MONICA_00D00909F004D0070007', '1', '1B'],
#  ['RWS01_MONICA_00D00909F004D0070007', '1', '2B'],
#  ['RWS01_MONICA_00D00909F004D0070007', '1', '3B'],
#  ['RWS01_MONICA_00D00909F004D0070007', '1', '4B'],
#  ['RWS01_MONICA_00D00909F004D007000B', '1', '9B'],
#  ['RWS01_MONICA_00D00909F004D007000B', '1', '10B'],
#  ['RWS01_MONICA_00D00909F004D007000B', '1', '11B'],
#  ['RWS01_MONICA_00D00909F004D007000B', '1', '12B'],
#  ['RWS01_MONICA_00D00909F004D0070187', '1', '1B'],
#  ['RWS01_MONICA_00D00909F004D0070187', '1', '2B'],
#  ['RWS01_MONICA_00D00909F004D0070187', '1', '3B'],
#  ['RWS01_MONICA_00D00909F004D0070187', '1', '4B'],
#  ['RWS01_MONICA_00D0090A982FD0070007', '1', '1B'],
#  ['RWS01_MONICA_00D0090A982FD0070007', '1', '2B'],
#  ['RWS01_MONICA_00D0090A982FD0070007', '1', '3B'],
#  ['RWS01_MONICA_00D0090A982FD0070007', '1', '4B'],
#  ['RWS01_MONICA_00D0090A982FD007000B', '1', '9B'],
#  ['RWS01_MONICA_00D0090A982FD007000B', '1', '10B']]

# %% [markdown]
# ### Volkskrant data
# The Dutch netwspaker [Volkskrant](http://www.volkskrant.nl) has a large archive of its articles online. We downloaded the years 2000 - 2016 and they are available on the Twente Hadoop cluster under: `/data/volkskrant`.

# %%
volkskrant = sqlContext.read.json("volkskrant.json.gz") 

volkskrant.show(5)

volkskrant.printSchema()
# Out:
# +--------+---+--------------------+-----+--------------------+--------------------+---------+--------------------+----+
# |category|day|                href|month|                text|                time|timeofday|               title|year|
# +--------+---+--------------------+-----+--------------------+--------------------+---------+--------------------+----+
# | Archief|  5|http://www.volksk...|    7|Een provocatieve ...|  5 juli 2011, 00:00|    00:00|Mensen uitlachen ...|2011|
# |Politiek| 18|http://www.volksk...|    3|Een euforisch gej...|18 maart 2015, 22:39|    22:39|'De boodschap van...|2015|
# |Economie| 21|http://www.volksk...|    6|De klant is konin...| 21 juni 2008, 02:47|    02:47|Klant geen koning...|2008|
# |Magazine|  4|http://www.volksk...|    1|Het gaat van kwaa...|4 januari 2013, 1...|    12:04|Indiase politicus...|2013|
# | Archief| 29|http://www.volksk...|    3|Chris Klomp vindt...|29 maart 2013, 00:00|    00:00|Uitgedaagd op Vol...|2013|
# +--------+---+--------------------+-----+--------------------+--------------------+---------+--------------------+----+
# only showing top 5 rows
#
# root
#  |-- category: string (nullable = true)
#  |-- day: long (nullable = true)
#  |-- href: string (nullable = true)
#  |-- month: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- time: string (nullable = true)
#  |-- timeofday: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: long (nullable = true)
